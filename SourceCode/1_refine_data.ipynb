# %% [markdown]
# Read file data

# %%
RAW_DATA_LINK = "data/0_raw_data.csv"
REFORMED_DATA_LINK = "data/1_reformed_data.csv"
REMOVE_UNKNOWN_DATA_LINK = "data/2_remove_unknown_data.csv"

# %%
import pandas as pd
import os

data = pd.read_csv(RAW_DATA_LINK, sep=";")
features = list(map(lambda x: x.replace('"', ''), data.columns.tolist()[0].split(";")))
rows = data.iloc[:, 0].str.split(";").tolist()
df = pd.DataFrame(rows, columns=features)
df = df.map(lambda x: x.replace('"', '') if isinstance(x, str) else x)
for column in df.columns:
    df[column] = pd.to_numeric(df[column], errors="coerce")
len(df)
# Out:
# 41180

# %%
import csv
with open(REFORMED_DATA_LINK, "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)

    writer.writerow(df.columns)

    for row in df.itertuples(index=False):
        writer.writerow(row)

# %%
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values, {df[col].isnull().sum()} missing values, {df[col].dtype} data type")
# Out:
# age: 78 unique values, 0 missing values, int64 data type
# job: 0 unique values, 41180 missing values, float64 data type
# marital: 0 unique values, 41180 missing values, float64 data type
# education: 0 unique values, 41180 missing values, float64 data type
# default: 0 unique values, 41180 missing values, float64 data type
# housing: 0 unique values, 41180 missing values, float64 data type
# loan: 0 unique values, 41180 missing values, float64 data type
# contact: 0 unique values, 41180 missing values, float64 data type
# month: 0 unique values, 41180 missing values, float64 data type
# day_of_week: 0 unique values, 41180 missing values, float64 data type
# duration: 1544 unique values, 0 missing values, int64 data type
# campaign: 42 unique values, 0 missing values, int64 data type
# pdays: 27 unique values, 0 missing values, int64 data type
# previous: 8 unique values, 0 missing values, int64 data type
# poutcome: 0 unique values, 41180 missing values, float64 data type
# emp.var.rate: 10 unique values, 0 missing values, float64 data type
# cons.price.idx: 26 unique values, 0 missing values, float64 data type
# cons.conf.idx: 26 unique values, 0 missing values, float64 data type
# euribor3m: 316 unique values, 0 missing values, float64 data type
# nr.employed: 11 unique values, 0 missing values, float64 data type
# y: 0 unique values, 41180 missing values, float64 data type

# %%
for column in df.select_dtypes(include="object").columns:
    print(f"\n--- {column} ---")
    print(df[column].value_counts())

# %%
import numpy as np

for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].replace('unknown', np.nan)

for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values, {df[col].isnull().sum()} missing values, {df[col].dtype} data type")

for column in df.select_dtypes(include="object").columns:
    print(f"\n--- {column} ---")
    print(df[column].value_counts())
# Out:
# age: 78 unique values, 0 missing values, int64 data type
# job: 0 unique values, 41180 missing values, float64 data type
# marital: 0 unique values, 41180 missing values, float64 data type
# education: 0 unique values, 41180 missing values, float64 data type
# default: 0 unique values, 41180 missing values, float64 data type
# housing: 0 unique values, 41180 missing values, float64 data type
# loan: 0 unique values, 41180 missing values, float64 data type
# contact: 0 unique values, 41180 missing values, float64 data type
# month: 0 unique values, 41180 missing values, float64 data type
# day_of_week: 0 unique values, 41180 missing values, float64 data type
# duration: 1544 unique values, 0 missing values, int64 data type
# campaign: 42 unique values, 0 missing values, int64 data type
# pdays: 27 unique values, 0 missing values, int64 data type
# previous: 8 unique values, 0 missing values, int64 data type
# poutcome: 0 unique values, 41180 missing values, float64 data type
# emp.var.rate: 10 unique values, 0 missing values, float64 data type
# cons.price.idx: 26 unique values, 0 missing values, float64 data type
# cons.conf.idx: 26 unique values, 0 missing values, float64 data type
# euribor3m: 316 unique values, 0 missing values, float64 data type
# nr.employed: 11 unique values, 0 missing values, float64 data type
# y: 0 unique values, 41180 missing values, float64 data type

# %%
with open(REMOVE_UNKNOWN_DATA_LINK, "w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)

    writer.writerow(df.columns)

    for row in df.itertuples(index=False):
        writer.writerow(row)
