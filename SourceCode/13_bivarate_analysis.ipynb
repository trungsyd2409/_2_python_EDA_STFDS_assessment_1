# %%
FIX_INVALID_DATA_LINK = "data/3_fix_invalid_data.csv"
import pandas as pd

df = pd.read_csv(FIX_INVALID_DATA_LINK)
print(df.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %% [markdown]
# Which customer's traits related to the decision to subcribe?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# get numerrical variables 
TARGET_COLUMN = "y"
numerical_variables = df.select_dtypes(include=["int64","float64"]).columns
print(numerical_variables)

for col in numerical_variables:
    plt.figure(figsize=(10,6))

    rate = pd.crosstab(
        df[col],
        df[TARGET_COLUMN],
        normalize="index",
    )["yes"] * 100
    rate.plot(kind="barh")
    #rate.sort_values().plot(kind="barh")

    plt.xlabel(f"Subscription rate (%) with {col}")
    plt.show()
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')
